# %%
import pandas as pd
from pathlib import Path

# %%
indicators = [
    {
        "domain": "Disease burden",
        "indicator": "Diabetes DALYs rate",
        "source": "IHME GBD",
        "data_type": "outcome",
        "brief_relevance": "Overall diabetes-related health loss"
    },
    {
        "domain": "Disease burden",
        "indicator": "Diabetes deaths rate",
        "source": "IHME GBD",
        "data_type": "outcome",
        "brief_relevance": "Mortality burden and severity"
    },
    {
        "domain": "Disease burden",
        "indicator": "Diabetes prevalence rate",
        "source": "IHME GBD",
        "data_type": "outcome",
        "brief_relevance": "Scale of diabetes in the population"
    },
    {
        "domain": "Demographic transition",
        "indicator": "Population aged 65+ (%)",
        "source": "World Bank",
        "data_type": "risk determinant",
        "brief_relevance": "Ageing increases chronic disease demand"
    },
    {
        "domain": "Lifestyle transition",
        "indicator": "Urban population (%)",
        "source": "World Bank",
        "data_type": "risk determinant",
        "brief_relevance": "Urbanisation can shift diet, physical activity, and care access"
    },
    {
        "domain": "Individual capability",
        "indicator": "Secondary school enrolment",
        "source": "World Bank",
        "data_type": "protective determinant",
        "brief_relevance": "Education supports health literacy and prevention capability"
    },
    {
        "domain": "Individual capability",
        "indicator": "Internet users (%)",
        "source": "World Bank",
        "data_type": "protective determinant",
        "brief_relevance": "Digital access supports health information and service access"
    },
    {
        "domain": "Economic capability",
        "indicator": "GDP per capita",
        "source": "World Bank",
        "data_type": "capacity determinant",
        "brief_relevance": "Indicates national resource capacity"
    },
    {
        "domain": "Health system freedom",
        "indicator": "Current health expenditure (% GDP)",
        "source": "World Bank / WHO",
        "data_type": "system capacity",
        "brief_relevance": "Indicates national investment in health"
    },
    {
        "domain": "Health system freedom",
        "indicator": "Out-of-pocket expenditure (% health expenditure)",
        "source": "World Bank / WHO",
        "data_type": "barrier determinant",
        "brief_relevance": "Indicates financial barriers to care"
    },
    {
        "domain": "Governance and civic capacity",
        "indicator": "Liberal democracy index",
        "source": "V-Dem / OWID",
        "data_type": "institutional determinant",
        "brief_relevance": "Proxy for civic freedom, accountability, and institutional openness"
    },
    {
        "domain": "Governance and civic capacity",
        "indicator": "Government effectiveness",
        "source": "World Bank WGI",
        "data_type": "institutional determinant",
        "brief_relevance": "Proxy for implementation capacity"
    },
]

# %%
construct_library = pd.DataFrame(indicators)

construct_library
# Out:
#                            domain  \
# 0                  Disease burden
# 1                  Disease burden
# 2                  Disease burden
# 3          Demographic transition
# 4            Lifestyle transition
# 5           Individual capability
# 6           Individual capability
# 7             Economic capability
# 8           Health system freedom
# 9           Health system freedom
# 10  Governance and civic capacity
# 11  Governance and civic capacity
#
#                                            indicator            source  \
# 0                                Diabetes DALYs rate          IHME GBD
# 1                               Diabetes deaths rate          IHME GBD
# 2                           Diabetes prevalence rate          IHME GBD
# 3                            Population aged 65+ (%)        World Bank
# 4                               Urban population (%)        World Bank
# 5                         Secondary school enrolment        World Bank
# ...

# %%
construct_library.to_csv(
    "../data/processed/construct_library.csv",
    index=False
)
